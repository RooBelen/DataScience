# %%
import numpy as np

# %%
import pandas as pd

# %%
pd.read_csv('LifeExpectancy.csv')
# Out:
#           Country  Year      Status  Life expectancy (men)  \
# 0     Afghanistan  2015  Developing                     70
# 1     Afghanistan  2014  Developing                     59
# 2     Afghanistan  2013  Developing                     79
# 3     Afghanistan  2012  Developing                     65
# 4     Afghanistan  2011  Developing                     76
# ...           ...   ...         ...                    ...
# 2933     Zimbabwe  2004  Developing                     67
# 2934     Zimbabwe  2003  Developing                     62
# 2935     Zimbabwe  2002  Developing                     50
# 2936     Zimbabwe  2001  Developing                     66
# 2937     Zimbabwe  2000  Developing                     55
#
#       Life expectancy(women)  Adult Mortality (men)  Adult Mortality (women)  \
# 0                         66                     67                       65
# 1                         67                     73                       85
# ...

# %%
expvida = pd.read_csv('LifeExpectancy.csv')

# %%
type(expvida)
# Out:
# pandas.core.frame.DataFrame

# %%
expvida.shape #filas y columnas
# Out:
# (2938, 25)

# %%
#¿Cual es el nombre de las columnas contenidas en expvida?  #VER como traer los titulos
arrayexpvida = np.array(expvida)
arrayexpvida[0, :]
# Out:
# array(['Afghanistan', 2015, 'Developing', 70, 66, 67, 65, 62, 0.01,
#        71.27962362, 40, 40, 1154, 19.1, 83, 6.0, 8.16, 65.0, 0.1,
#        584.25921, 33736494.0, 17.2, 17.3, 0.479, 10.1], dtype=object)

# %%
#Inspecciona las primeras 10 filas de expvida
print(arrayexpvida[0: 10])
# Out:
# [['Afghanistan' 2015 'Developing' 70 66 67 65 62 0.01 71.27962362 40 40
#   1154 19.1 83 6.0 8.16 65.0 0.1 584.25921 33736494.0 17.2 17.3 0.479
#   10.1]
#  ['Afghanistan' 2014 'Developing' 59 67 73 85 64 0.01 73.52358168 20 43
#   492 18.6 86 58.0 8.18 62.0 0.1 612.696514 327582.0 17.5 17.5 0.476 10.0]
#  ['Afghanistan' 2013 'Developing' 79 51 87 67 66 0.01 73.21924272 25 39
#   430 18.1 89 62.0 8.13 64.0 0.1 631.744976 31731688.0 17.7 17.7 0.47 9.9]
#  ['Afghanistan' 2012 'Developing' 65 81 63 91 69 0.01 78.1842153 54 42
#   2787 17.6 93 67.0 8.52 67.0 0.1 669.959 3696958.0 17.9 18.0 0.463 9.8]
#  ['Afghanistan' 2011 'Developing' 76 75 57 72 71 0.01 7.097108703 48 24
#   3013 17.2 97 68.0 7.87 68.0 0.1 63.537231 2978599.0 18.2 18.2 0.454 9.5]
#  ['Afghanistan' 2010 'Developing' 51 77 71 57 74 0.01 79.67936736 51 30
#   1989 16.7 102 66.0 9.2 66.0 0.1 553.32894 2883167.0 18.4 18.4 0.448 9.2]
#  ['Afghanistan' 2009 'Developing' 77 67 84 100 77 0.01 56.76221682 41 47
# ...

# %%
# Inspecciono las ultimas filas  #VER
print(arrayexpvida[0: -10])
# Out:
# [['Afghanistan' 2015 'Developing' ... 17.3 0.479 10.1]
#  ['Afghanistan' 2014 'Developing' ... 17.5 0.476 10.0]
#  ['Afghanistan' 2013 'Developing' ... 17.7 0.47 9.9]
#  ...
#  ['Zimbabwe' 2012 'Developing' ... 6.4 0.464 9.8]
#  ['Zimbabwe' 2011 'Developing' ... 6.7 0.452 10.1]
#  ['Zimbabwe' 2010 'Developing' ... 7.0 0.436 10.0]]

# %%
#¿Que tipos de datos contiene cada una de las columnas de expvida?
